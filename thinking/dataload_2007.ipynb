# %% [markdown]
# ### Import & Data load

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
from tqdm import tqdm
import os
import seaborn as sns
import re

_dir = '_20'
_month = '07'
_file_ls = [i for i in os.listdir(_dir) if re.split('/|_',_dir)[-1]+_month in re.split('_', i)]
freez2005 = pd.read_csv(os.path.join(_dir, [i for i in _file_ls if 'freezer' in i][0]))
suth2005 = pd.read_csv(os.path.join(_dir, [i for i in _file_ls if 'suth' in i][0]))


freez2005.columns
freez2005.columns = ['freezer_id', 'gw_time', 'status', 'fan_run', 'fan_trip',
       'freez_run', 'freez_trip', 'defrost', 'ctrl_mode', 'ctrl_operation',
       'operation', 'run_time', 'insert_dt']

suth2005.columns
suth2005.columns = ['sensor_id', 'gw_time', 'status', 'color_list', 'avg_temperature',
       'avg_humidity', 'temperature', 'humidity', 'battery', 'available',
       'insert_dt']

# %matplotlib inline

# %% [markdown]
# ### SCM 창고(19) sensor, freezer 추출, Column 선별, Type 재설정

# %%
# No. 19
sensor_id = [329, 332, 335]
freezer_id = [344, 362, 368]

df_sensor = pd.DataFrame()
df_freezer = pd.DataFrame()

for elem in sensor_id:
    df_sensor = pd.concat([df_sensor, suth2005[suth2005['sensor_id'] == elem]])
    print("sensor id {}의 데이터 개수: {}".format(elem, len(suth2005[suth2005['sensor_id'] == elem])))
for elem in freezer_id:
    df_freezer = pd.concat([df_freezer, freez2005[freez2005['freezer_id'] == elem]])
    print("freezer id {}의 데이터 개수: {}".format(elem, len(df_freezer[df_freezer['freezer_id'] == elem])))

df_sensor.sort_values(by = ['sensor_id', 'gw_time'])
df_freezer.sort_values(by = ['freezer_id', 'gw_time'])

print('sensor: ',df_sensor['sensor_id'].unique())
print('freezer: ', df_freezer['freezer_id'].unique())

df_sensor = df_sensor.drop(columns = ['color_list','insert_dt'])
df_freezer = df_freezer.drop(columns= ['insert_dt'])

df_sensor['gw_time'] = pd.to_datetime(df_sensor['gw_time'])
df_freezer['gw_time'] = pd.to_datetime(df_freezer['gw_time'])
# Out:
# sensor id 329의 데이터 개수: 88599
# sensor id 332의 데이터 개수: 88599
# sensor id 335의 데이터 개수: 88599
# freezer id 344의 데이터 개수: 90050
# freezer id 362의 데이터 개수: 90050
# freezer id 368의 데이터 개수: 90050
# sensor:  [329 332 335]
# freezer:  [344 362 368]

# %% [markdown]
# # Sensor 결측치 처리
# - sensor의 available == 0 일 때, 결측치 발생
# - 결측치는 모두 -99999로 되어있음

# %%
df_sensor.isnull().sum()
# Out:
# sensor_id          0
# gw_time            0
# status             0
# avg_temperature    0
# avg_humidity       0
# temperature        0
# humidity           0
# battery            0
# available          0
# dtype: int64

# %%
condition = df_sensor.values == -99999
df_sensor[condition] = np.nan

# %% [markdown]
# # Position

# %%
# sensor_pos = {
#     "290": {"x": 2, "y": 3},
#     "293": {"x": 5, "y": 3},
#     "296": {"x": 3, "y": 8},
#     "299": {"x": 4, "y": 14},
#     "302": {"x": 4, "y": 5}
# }
# freezer_pos = {
#     "308": {"x": 2, "y": 1},
#     "314": {"x": 6, "y": 1},
#     "320": {"x": 8, "y": 10},
#     "326": {"x": 4, "y": 17}
# }

# sensor_pos = pd.DataFrame(sensor_pos).T
# freezer_pos = pd.DataFrame(freezer_pos).T

# sensor_pos = sensor_pos.reset_index()
# freezer_pos = freezer_pos.reset_index()
# pos = pd.concat([sensor_pos,freezer_pos])

# %%
# no. 19
sensor_pos = {
    "329": {"x": 16, "y": 5},
    "332": {"x": 10, "y": 5},
    "335": {"x": 4, "y": 5},
    "338": {"x": 18, "y": 1}
}
freezer_pos = {
    "344": {"x": 16, "y": 0},
    "344-1": {"x": 14, "y": 0},
    "362": {"x": 11, "y": 0},
    "362-1": {"x": 8, "y": 0},
    "368": {"x": 4, "y": 0},
    "368-1": {"x": 2, "y": 0}
}
door_pos = {
    "door": {"x": 4, "y": 9}
}

sensor_pos = pd.DataFrame(sensor_pos).T
sensor_pos['type'] = ['sensor']*len(sensor_pos)
freezer_pos = pd.DataFrame(freezer_pos).T
freezer_pos['type'] = ['freezer']*len(freezer_pos)
door_pos = pd.DataFrame(door_pos).T
door_pos['type']= ['door']*len(door_pos)
sensor_pos = sensor_pos.reset_index()
freezer_pos = freezer_pos.reset_index()
door_pos = door_pos.reset_index()
pos = pd.concat([sensor_pos,freezer_pos,door_pos])

# %%
def display_position(pos):
    plt.figure(figsize = (12,10))
    sns.scatterplot(
        x = 'x', 
        y = 'y', 
        data = pos, 
        hue = 'index', 
        style='type',
        s = 70
        )
    # sensor
    for _id in sensor_id:
        x = sensor_pos[sensor_pos['index'] == str(_id)]['x']
        y = sensor_pos[sensor_pos['index'] == str(_id)]['y']
        plt.annotate(str(_id)+'(sensor)', xy = (x,y), xytext=(x, y-1), fontsize = 10, ha = 'center', arrowprops=dict(facecolor='black', width=1, shrink=0.1, headwidth=10)) 
    
    # # freezer
    for _id in freezer_id:
        x = freezer_pos[freezer_pos['index'] == str(_id)]['x']
        y = freezer_pos[freezer_pos['index'] == str(_id)]['y']
        plt.annotate(str(_id)+'(freezer)', xy = (x,y), xytext=(x, y-1), fontsize = 10, ha = 'center', arrowprops=dict(facecolor='black', width=1, shrink=0.1, headwidth=10)) 

    plt.annotate('door', xy=(pos[pos['type'] == 'door']['x'], pos[pos['type'] == 'door']['y']), xytext=(pos[pos['type'] == 'door']['x'],pos[pos['type'] == 'door']['y']-1),
                fontsize=10, ha='center',
                arrowprops=dict(facecolor='blue', width=1, shrink=0.1, headwidth=10))

# %%
display_position(pos)

# %% [markdown]
# # Mapping

# %% [markdown]
# ## melt id to columns

# %%
df0 = df_freezer.copy()['gw_time']
for _id in df_freezer['freezer_id'].unique():
    df_tmp = df_freezer[df_freezer['freezer_id'] == _id]
    df_tmp.reset_index(drop = True)
    df_tmp.drop(columns= ['freezer_id'], inplace= True)
    df_tmp.columns = ['gw_time']+[x+'_'+str(_id) for x in df_freezer.columns if x not in ['freezer_id','gw_time']]
    df0 = pd.merge(df0, df_tmp, on = 'gw_time', how = 'outer')

melted_freezer = df0
# Out:
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\1092712872.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.drop(columns= ['freezer_id'], inplace= True)
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\1092712872.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.drop(columns= ['freezer_id'], inplace= True)
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\1092712872.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.drop(columns= ['freezer_id'], inplace= True)

# %%
df0 = df_sensor.copy()['gw_time']
for _id in df_sensor['sensor_id'].unique():
    df_tmp = df_sensor[df_sensor['sensor_id'] == _id]
    df_tmp.reset_index(drop = True)
    df_tmp.drop(columns= ['sensor_id'], inplace= True)
    df_tmp.columns = ['gw_time']+[x+'_'+str(_id) for x in df_sensor.columns if x not in ['sensor_id','gw_time']]
    df0 = pd.merge(df0, df_tmp, on = 'gw_time', how = 'outer')

melted_sensor = df0
# Out:
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\1020320345.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.drop(columns= ['sensor_id'], inplace= True)
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\1020320345.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.drop(columns= ['sensor_id'], inplace= True)
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\1020320345.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.drop(columns= ['sensor_id'], inplace= True)

# %%
melted_df = pd.merge_asof(
    left=melted_sensor.sort_values(by="gw_time"),
    right=melted_freezer.sort_values(by="gw_time"),
    on="gw_time",
    direction="forward",
    tolerance=pd.Timedelta("30 second"),
    allow_exact_matches=False,
    suffixes=("_freezer", "_sensor"),
)
melted_df.drop_duplicates(inplace= True, ignore_index= True)
melted_df.index = melted_df['gw_time']

# %%
null_indexs  = melted_df[melted_df['freez_run_344'].isnull()].index
null_columns = melted_df[melted_df['freez_run_344'].isnull()].columns

# %%
for col in null_columns[1:]:
    melted_df[col] = melted_df[col].interpolate(method='time')

melted_df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## delta temperture (dT)

# %%
# melted_df['dT_335'] = melted_df['temperature_335'] - melted_df.temperature_335.shift(1).fillna(melted_df['temperature_335'][0])
# melted_df['dT_332'] = melted_df['temperature_332'] - melted_df.temperature_332.shift(1).fillna(melted_df['temperature_332'][0])
# melted_df['dT_329'] = melted_df['temperature_329'] - melted_df.temperature_329.shift(1).fillna(melted_df['temperature_329'][0])

for _id in sensor_id:
    melted_df['dT_'+str(_id)] =  melted_df['temperature_'+str(_id)] - melted_df['temperature_'+str(_id)].shift(1).fillna(melted_df['temperature_'+str(_id)][0])

# %%
test_figure = melted_df[4000:4500]
plt.figure(figsize = (24,10))

plt.subplot(2,1,1)
plt.title("freez_run of freezers")
w = 0
for _id in freezer_id:
    plt.plot(test_figure['gw_time'],test_figure['fan_run'+'_'+str(_id)]+w, label = 'freez_run'+'_'+str(_id),alpha = 1)
    w+= 0.015
plt.ylabel('freez_run')
plt.legend()

plt.subplot(2,1,2)
plt.title('temperature of sensors')
for _id in sensor_id:
    plt.plot(test_figure['gw_time'],test_figure['temperature'+'_'+str(_id)], label = 'temperature'+'_'+str(_id),alpha = 1)
plt.ylabel('temperature')
plt.legend()
plt.show()

i = 1
colors = ['tab:blue','tab:orange','tab:green']
plt.figure(figsize = (24,5))
for _id in sensor_id:
    plt.subplot(3,1,i)
    plt.title('delta temperature of sensor '+str(_id), loc= 'center')
    plt.plot(test_figure['gw_time'],test_figure['dT'+'_'+str(_id)], label = 'dT'+'_'+str(_id),alpha = 1, color = colors[i-1])
    plt.plot(test_figure['gw_time'], [0]*len(test_figure), color = 'r', alpha = 0.6)
    plt.ylabel('delta temperature')
    i+=1
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace=0.4)
plt.show()

# %% [markdown]
# # 간단한 모델 만들기

# %%
import math
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping

# %%
df = melted_df.copy()
df.isnull().sum().sum()
# Out:
# 0

# %%
for elem in sensor_id:
    df['temperature_'+str(elem)+'_prime'] = df['temperature_'+str(elem)].shift(1)

import random
for col in ['operation_'+ str(_id) for _id in freezer_id]:
    random_list = []
    for i in range(len(df)):
        random_list.append(random.randint(0,1))
    df[col+'_random'] = random_list
    df[col+'_zero'] = [0]*len(df)
    df[col+'_one'] = [1]*len(df)

df = df.dropna()

# %%
# from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()
# scale_cols =['dT_'+str(_id) for _id in sensor_id]+['temperature_'+str(_id) for _id in sensor_id]+['humidity_'+str(_id) for _id in sensor_id]
# for col in scale_cols:
#     df[col] = scaler.fit_transform(df[col].values.reshape(-1,1))

# %%
TEST_SIZE = 8000
train_raw = df[:-TEST_SIZE]
test = df[-TEST_SIZE:]
train_raw.shape, test.shape
# Out:
# ((80598, 67), (8000, 67))

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scale_cols =['dT_'+str(_id) for _id in sensor_id]+['temperature_'+str(_id) for _id in sensor_id]+['humidity_'+str(_id) for _id in sensor_id] + ['temperature_'+str(_id)+'_prime' for _id in sensor_id]
for col in scale_cols:
    train_raw[col] = scaler.fit_transform(train_raw[col].values.reshape(-1,1))
    test[col] = scaler.transform(test[col].values.reshape(-1,1))
# Out:
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\2132141817.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_raw[col] = scaler.fit_transform(train_raw[col].values.reshape(-1,1))
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\2132141817.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[col] = scaler.transform(test[col].values.reshape(-1,1))
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\2132141817.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_raw[col] = scaler.fit_transform(train_raw[col].values.reshape(-1,1))
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\2132141817.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[col] = scaler.transform(test[col].values.reshape(-1,1))
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\2132141817.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_raw[col] = scaler.fit_transform(train_raw[col].values.reshape(-1,1))
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\2132141817.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[col] = scaler.transform(test[col].values.reshape(-1,1))
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\2132141817.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_raw[col] = scaler.fit_transform(train_raw[col].values.reshape(-1,1))
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\2132141817.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[col] = scaler.transform(test[col].values.reshape(-1,1))
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\2132141817.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_raw[col] = scaler.fit_transform(train_raw[col].values.reshape(-1,1))
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\2132141817.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[col] = scaler.transform(test[col].values.reshape(-1,1))
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\2132141817.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_raw[col] = scaler.fit_transform(train_raw[col].values.reshape(-1,1))
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\2132141817.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[col] = scaler.transform(test[col].values.reshape(-1,1))
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\2132141817.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_raw[col] = scaler.fit_transform(train_raw[col].values.reshape(-1,1))
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\2132141817.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[col] = scaler.transform(test[col].values.reshape(-1,1))
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\2132141817.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_raw[col] = scaler.fit_transform(train_raw[col].values.reshape(-1,1))
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\2132141817.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[col] = scaler.transform(test[col].values.reshape(-1,1))
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\2132141817.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_raw[col] = scaler.fit_transform(train_raw[col].values.reshape(-1,1))
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\2132141817.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[col] = scaler.transform(test[col].values.reshape(-1,1))
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\2132141817.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_raw[col] = scaler.fit_transform(train_raw[col].values.reshape(-1,1))
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\2132141817.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[col] = scaler.transform(test[col].values.reshape(-1,1))
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\2132141817.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_raw[col] = scaler.fit_transform(train_raw[col].values.reshape(-1,1))
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\2132141817.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[col] = scaler.transform(test[col].values.reshape(-1,1))
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\2132141817.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_raw[col] = scaler.fit_transform(train_raw[col].values.reshape(-1,1))
# C:\Users\Intellicode\AppData\Local\Temp\ipykernel_8312\2132141817.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[col] = scaler.transform(test[col].values.reshape(-1,1))

# %%
def make_dataset(data, label, window_size=20):
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    return np.array(feature_list), np.array(label_list)

# %%
# feature_cols = ['fan_run_344',
#  'fan_run_362',
#  'fan_run_368',
#  'fan_trip_344',
#  'fan_trip_362',
#  'fan_trip_368',
#  'freez_run_344',
#  'freez_run_362',
#  'freez_run_368',
#  'freez_trip_344',
#  'freez_trip_362',
#  'freez_trip_368',
#  'defrost_344',
#  'defrost_362',
#  'defrost_368',
#  'ctrl_mode_344',
#  'ctrl_mode_362',
#  'ctrl_mode_368',
#  'ctrl_operation_344',
#  'ctrl_operation_362',
#  'ctrl_operation_368',
#  'operation_344',
#  'operation_362',
#  'operation_368','temperature_329_prime']
# feature_cols = [
#  'operation_344',
#  'operation_362',
#  'operation_368','temperature_329_prime']

feature_cols = [
 'operation_344_random',
 'operation_362_random',
 'operation_368_random','temperature_329_prime']
# feature_cols = ['temperature_329_prime']

label_cols = ['temperature_329']

# %%
train_feature = train_raw[feature_cols]
train_label = train_raw[label_cols]

# train dataset
train_feature, train_label = make_dataset(train_feature, train_label, 20)

# train, validation set 생성
from sklearn.model_selection import train_test_split
x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)

x_train.shape, x_valid.shape
# ((57676, 20, 21), (14419, 20, 21))
# Out:
# ((64462, 20, 4), (16116, 20, 4))

# %%
test_feature = test[feature_cols]
test_label = test[label_cols]

# test dataset (실제 예측 해볼 데이터)
test_feature, test_label = make_dataset(test_feature, test_label, 20)
test_feature.shape, test_label.shape
# Out:
# ((7980, 20, 4), (7980, 1))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import LSTM

model = Sequential()
model.add(LSTM(64, 
               input_shape=(train_feature.shape[1], train_feature.shape[2]), 
               activation='tanh', 
               return_sequences=False)
          )
model.add(Dense(1))

# %%
np.save('train_feature.npy', train_feature)
np.save('train_label.npy', train_label)

# %%
model.compile(loss='mean_squared_error', optimizer='adam')
early_stop = EarlyStopping(monitor='val_loss', patience=5)
filename = './tmp_checkpoint.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

history = model.fit(x_train, y_train, 
                    epochs=100, 
                    batch_size=256,
                    validation_data=(x_valid, y_valid), 
                    callbacks=[early_stop, checkpoint],
                    shuffle = False)
# Out:
# Epoch 1/100
# 250/252 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 1: val_loss improved from inf to 0.00012, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 5s 10ms/step - loss: 0.0021 - val_loss: 1.1633e-04
# Epoch 2/100
# 246/252 [============================>.] - ETA: 0s - loss: 1.5747e-04
# Epoch 2: val_loss improved from 0.00012 to 0.00007, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 9ms/step - loss: 1.5522e-04 - val_loss: 7.3129e-05
# Epoch 3/100
# 250/252 [============================>.] - ETA: 0s - loss: 1.5415e-04
# Epoch 3: val_loss improved from 0.00007 to 0.00005, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 9ms/step - loss: 1.5396e-04 - val_loss: 5.2337e-05
# Epoch 4/100
# 247/252 [============================>.] - ETA: 0s - loss: 1.5667e-04
# Epoch 4: val_loss improved from 0.00005 to 0.00004, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 8ms/step - loss: 1.5469e-04 - val_loss: 4.1602e-05
# Epoch 5/100
# 248/252 [============================>.] - ETA: 0s - loss: 1.4899e-04
# Epoch 5: val_loss improved from 0.00004 to 0.00004, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 9ms/step - loss: 1.4757e-04 - val_loss: 3.6255e-05
# Epoch 6/100
# 249/252 [============================>.] - ETA: 0s - loss: 1.3192e-04
# Epoch 6: val_loss improved from 0.00004 to 0.00003, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 8ms/step - loss: 1.3113e-04 - val_loss: 3.1976e-05
# Epoch 7/100
# 249/252 [============================>.] - ETA: 0s - loss: 1.1498e-04
# Epoch 7: val_loss improved from 0.00003 to 0.00003, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 9ms/step - loss: 1.1430e-04 - val_loss: 2.8060e-05
# Epoch 8/100
# 249/252 [============================>.] - ETA: 0s - loss: 1.0269e-04
# Epoch 8: val_loss improved from 0.00003 to 0.00002, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 9ms/step - loss: 1.0209e-04 - val_loss: 2.4736e-05
# Epoch 9/100
# 249/252 [============================>.] - ETA: 0s - loss: 9.3811e-05
# Epoch 9: val_loss improved from 0.00002 to 0.00002, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 8ms/step - loss: 9.3245e-05 - val_loss: 2.2157e-05
# Epoch 10/100
# 252/252 [==============================] - ETA: 0s - loss: 8.6084e-05
# Epoch 10: val_loss improved from 0.00002 to 0.00002, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 8ms/step - loss: 8.6084e-05 - val_loss: 2.0096e-05
# Epoch 11/100
# 246/252 [============================>.] - ETA: 0s - loss: 8.1007e-05
# Epoch 11: val_loss improved from 0.00002 to 0.00002, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 8ms/step - loss: 7.9647e-05 - val_loss: 1.8239e-05
# Epoch 12/100
# 246/252 [============================>.] - ETA: 0s - loss: 7.4721e-05
# Epoch 12: val_loss improved from 0.00002 to 0.00002, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 8ms/step - loss: 7.3481e-05 - val_loss: 1.6500e-05
# Epoch 13/100
# 248/252 [============================>.] - ETA: 0s - loss: 6.8104e-05
# Epoch 13: val_loss improved from 0.00002 to 0.00002, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 8ms/step - loss: 6.7435e-05 - val_loss: 1.5020e-05
# Epoch 14/100
# 248/252 [============================>.] - ETA: 0s - loss: 6.2362e-05
# Epoch 14: val_loss improved from 0.00002 to 0.00001, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 8ms/step - loss: 6.1758e-05 - val_loss: 1.3981e-05
# Epoch 15/100
# 246/252 [============================>.] - ETA: 0s - loss: 5.7963e-05
# Epoch 15: val_loss improved from 0.00001 to 0.00001, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 9ms/step - loss: 5.7019e-05 - val_loss: 1.3213e-05
# Epoch 16/100
# 250/252 [============================>.] - ETA: 0s - loss: 5.3112e-05
# Epoch 16: val_loss improved from 0.00001 to 0.00001, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 9ms/step - loss: 5.2969e-05 - val_loss: 1.2432e-05
# Epoch 17/100
# 249/252 [============================>.] - ETA: 0s - loss: 4.8878e-05
# Epoch 17: val_loss improved from 0.00001 to 0.00001, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 9ms/step - loss: 4.8562e-05 - val_loss: 1.1425e-05
# Epoch 18/100
# 250/252 [============================>.] - ETA: 0s - loss: 4.3528e-05
# Epoch 18: val_loss improved from 0.00001 to 0.00001, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 9ms/step - loss: 4.3394e-05 - val_loss: 9.6612e-06
# Epoch 19/100
# 247/252 [============================>.] - ETA: 0s - loss: 3.7211e-05
# Epoch 19: val_loss improved from 0.00001 to 0.00001, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 9ms/step - loss: 3.6695e-05 - val_loss: 8.3311e-06
# Epoch 20/100
# 251/252 [============================>.] - ETA: 0s - loss: 4.1843e-05
# Epoch 20: val_loss improved from 0.00001 to 0.00001, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 9ms/step - loss: 4.1769e-05 - val_loss: 7.8543e-06
# Epoch 21/100
# 247/252 [============================>.] - ETA: 0s - loss: 3.8992e-05
# Epoch 21: val_loss improved from 0.00001 to 0.00001, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 9ms/step - loss: 3.8413e-05 - val_loss: 7.3833e-06
# Epoch 22/100
# 246/252 [============================>.] - ETA: 0s - loss: 3.8852e-05
# Epoch 22: val_loss improved from 0.00001 to 0.00001, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 9ms/step - loss: 3.8126e-05 - val_loss: 7.0819e-06
# Epoch 23/100
# 246/252 [============================>.] - ETA: 0s - loss: 3.7731e-05
# Epoch 23: val_loss improved from 0.00001 to 0.00001, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 9ms/step - loss: 3.7017e-05 - val_loss: 6.6881e-06
# Epoch 24/100
# 246/252 [============================>.] - ETA: 0s - loss: 3.6819e-05
# Epoch 24: val_loss improved from 0.00001 to 0.00001, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 9ms/step - loss: 3.6121e-05 - val_loss: 6.4520e-06
# Epoch 25/100
# 250/252 [============================>.] - ETA: 0s - loss: 3.6052e-05
# Epoch 25: val_loss improved from 0.00001 to 0.00001, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 9ms/step - loss: 3.5897e-05 - val_loss: 6.2096e-06
# Epoch 26/100
# 246/252 [============================>.] - ETA: 0s - loss: 3.5673e-05
# Epoch 26: val_loss improved from 0.00001 to 0.00001, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 9ms/step - loss: 3.4988e-05 - val_loss: 6.0215e-06
# Epoch 27/100
# 251/252 [============================>.] - ETA: 0s - loss: 3.4419e-05
# Epoch 27: val_loss improved from 0.00001 to 0.00001, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 9ms/step - loss: 3.4348e-05 - val_loss: 5.8711e-06
# Epoch 28/100
# 252/252 [==============================] - ETA: 0s - loss: 3.3657e-05
# Epoch 28: val_loss improved from 0.00001 to 0.00001, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 9ms/step - loss: 3.3657e-05 - val_loss: 5.7401e-06
# Epoch 29/100
# 252/252 [==============================] - ETA: 0s - loss: 3.2569e-05
# Epoch 29: val_loss improved from 0.00001 to 0.00001, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 9ms/step - loss: 3.2569e-05 - val_loss: 5.6076e-06
# Epoch 30/100
# 251/252 [============================>.] - ETA: 0s - loss: 3.2054e-05
# Epoch 30: val_loss improved from 0.00001 to 0.00001, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 9ms/step - loss: 3.1989e-05 - val_loss: 5.4910e-06
# Epoch 31/100
# 252/252 [==============================] - ETA: 0s - loss: 3.0922e-05
# Epoch 31: val_loss improved from 0.00001 to 0.00001, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 10ms/step - loss: 3.0922e-05 - val_loss: 5.3543e-06
# Epoch 32/100
# 248/252 [============================>.] - ETA: 0s - loss: 3.0503e-05
# Epoch 32: val_loss improved from 0.00001 to 0.00001, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 2s 9ms/step - loss: 3.0147e-05 - val_loss: 5.2205e-06
# Epoch 33/100
# 251/252 [============================>.] - ETA: 0s - loss: 2.9468e-05
# Epoch 33: val_loss improved from 0.00001 to 0.00001, saving model to .\tmp_checkpoint.h5
# 252/252 [==============================] - 3s 10ms/step - loss: 2.9413e-05 - val_loss: 5.1094e-06
# Epoch 34/100
# 252/252 [==============================] - ETA: 0s - loss: 2.8970e-05
# Epoch 34: val_loss did not improve from 0.00001
# 252/252 [==============================] - 3s 10ms/step - loss: 2.8970e-05 - val_loss: 5.1758e-06
# Epoch 35/100
# 251/252 [============================>.] - ETA: 0s - loss: 3.1091e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[88], line 6
#       3 filename = './tmp_checkpoint.h5'
#       4 checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
# ----> 6 history = model.fit(x_train, y_train,
#       7                     epochs=100,
#       8                     batch_size=256,
#       9                     validation_data=(x_valid, y_valid),
#      10                     callbacks=[early_stop, checkpoint],
#      11                     shuffle = False)
#
# File c:\project\jm\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\project\jm\lib\site-packages\keras\engine\training.py:1606, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1591 if getattr(self, "_eval_data_handler", None) is None:
#    1592     self._eval_data_handler = data_adapter.get_data_handler(
#    1593         x=val_x,
#    1594         y=val_y,
#    (...)
#    1604         steps_per_execution=self._steps_per_execution,
#    1605     )
# -> 1606 val_logs = self.evaluate(
#    1607     x=val_x,
#    1608     y=val_y,
#    1609     sample_weight=val_sample_weight,
#    1610     batch_size=validation_batch_size or batch_size,
#    1611     steps=validation_steps,
#    1612     callbacks=callbacks,
#    1613     max_queue_size=max_queue_size,
#    1614     workers=workers,
#    1615     use_multiprocessing=use_multiprocessing,
#    1616     return_dict=True,
#    1617     _use_cached_eval_dataset=True,
#    1618 )
#    1619 val_logs = {
#    1620     "val_" + name: val for name, val in val_logs.items()
#    1621 }
#    1622 epoch_logs.update(val_logs)
#
# File c:\project\jm\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\project\jm\lib\site-packages\keras\engine\training.py:1942, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1940 self.reset_metrics()
#    1941 with data_handler.catch_stop_iteration():
# -> 1942     for step in data_handler.steps():
#    1943         with tf.profiler.experimental.Trace(
#    1944             "test", step_num=step, _r=1
#    1945         ):
#    1946             callbacks.on_test_batch_begin(step)
#
# File c:\project\jm\lib\site-packages\keras\engine\data_adapter.py:1374, in DataHandler.steps(self)
#    1372 if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1373     break
# -> 1374 original_spe = self._steps_per_execution.numpy().item()
#    1375 can_run_full_execution = (
#    1376     original_spe == 1
#    1377     or self._inferred_steps is None
#    1378     or self._inferred_steps - self._current_step >= original_spe
#    1379 )
#    1381 if can_run_full_execution:
#
# File c:\project\jm\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:637, in BaseResourceVariable.numpy(self)
#     635 def numpy(self):
#     636   if context.executing_eagerly():
# --> 637     return self.read_value().numpy()
#     638   raise NotImplementedError(
#     639       "numpy() is only available when eager execution is enabled.")
#
# File c:\project\jm\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:725, in BaseResourceVariable.read_value(self)
#     716 """Constructs an op which reads the value of this variable.
#     717
#     718 Should be used when there are multiple reads, or when it is desirable to
#    (...)
#     722   The value of the variable.
#     723 """
#     724 with ops.name_scope("Read"):
# --> 725   value = self._read_variable_op()
#     726 # Return an identity so it can get placed on whatever device the context
#     727 # specifies instead of the device where the variable is.
#     728 return array_ops.identity(value)
#
# File c:\project\jm\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:704, in BaseResourceVariable._read_variable_op(self, no_copy)
#     702       result = read_and_set_handle(no_copy)
#     703 else:
# --> 704   result = read_and_set_handle(no_copy)
#     706 if not context.executing_eagerly():
#     707   # Note that if a control flow context is active the input of the read op
#     708   # might not actually be the handle. This line bypasses it.
#     709   tape.record_operation(
#     710       "ReadVariableOp", [result], [self.handle],
#     711       backward_function=lambda x: [x],
#     712       forward_function=lambda x: [x])
#
# File c:\project\jm\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:694, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     692 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     693   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 694 result = gen_resource_variable_ops.read_variable_op(
#     695     self.handle, self._dtype)
#     696 _maybe_set_handle_data(self._dtype, self.handle, result)
#     697 return result
#
# File c:\project\jm\lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py:524, in read_variable_op(resource, dtype, name)
#     522 if tld.is_eager:
#     523   try:
# --> 524     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     525       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     526     return _result
#     527   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# weight 로딩
model.load_weights(filename)

# 예측
pred = model.predict(test_feature)
# Out:
# 250/250 [==============================] - 1s 3ms/step

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
print("MSE: ", mean_squared_error(test_label, pred))
print("MAE: ", mean_absolute_error(test_label, pred))
plt.figure(figsize=(12, 9))
plt.plot(test_label, label='actual')
plt.plot(pred, label='prediction')
plt.legend()
plt.show()
# Out:
# MSE:  8.485901521147833e-06
# MAE:  0.0021237177298260184

# %%
_temp_scaler = MinMaxScaler()
_temp_scaler.fit(train_raw['temperature_329'].values.reshape(-1,1))
# Out:
# MinMaxScaler()

# %%
plt.figure(figsize=(20, 6))
plt.plot(_temp_scaler.inverse_transform(test_label), label='actual')
plt.plot(_temp_scaler.inverse_transform(pred), label='prediction')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 6))
plt.plot(_temp_scaler.inverse_transform(test_label[:200]), label='actual')
plt.plot(_temp_scaler.inverse_transform(pred[:200]), label='prediction')
plt.legend()
plt.show()

# %%
train_raw[label_cols]
# Out:
#                      temperature_329
# gw_time
# 2021-02-01 00:00:34         0.203579
# 2021-02-01 00:01:04         0.203579
# 2021-02-01 00:01:35         0.203579
# 2021-02-01 00:02:05         0.205817
# 2021-02-01 00:02:35         0.203579
# ...                              ...
# 2021-02-26 04:51:39         0.617450
# 2021-02-26 04:52:09         0.615213
# 2021-02-26 04:52:39         0.615213
# 2021-02-26 04:53:10         0.617450
# 2021-02-26 04:53:40         0.617450
#
# [72128 rows x 1 columns]
